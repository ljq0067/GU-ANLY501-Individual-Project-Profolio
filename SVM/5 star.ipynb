# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# reading in data
data = pd.read_csv('review_count1.csv')
data_train = data
# removing labels
data = data.iloc[:, 2:]

## wordcloud
wordsForCount = []
for label in set(data.columns):
    wordcount = sum(data[label])
    for i in range(int(wordcount)):
        wordsForCount.append(str(label))

wordsForCount = " ".join(wordsForCount)  # turning list of strings into one string
wordcloud = WordCloud(collocations=False).generate(wordsForCount)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from sklearn.model_selection import train_test_split

TrainDF, TestDF = train_test_split(data_train, test_size=0.2)
y_test=TestDF["LABEL"]
x_test = TestDF.drop(["LABEL"], axis=1)
## Train data
y_train=TrainDF["LABEL"]
x_train = TrainDF.drop(["LABEL"], axis=1)

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns

classifier=svm.SVC(kernel="linear", C=1)
classifier.fit(x_train, y_train)

dt_pred = classifier.predict(x_train)

bn_matrix = pd.DataFrame(confusion_matrix(y_train, dt_pred),
                         index=classifier.classes_,
                         columns=classifier.classes_)

plt.figure()
print("\nThe confusion matrix is:")
ax = sns.heatmap(bn_matrix,annot=True, fmt='.4g', vmin=0, vmax=200)
plt.show()


print(classification_report(y_train, dt_pred))
# Out:
# The confusion matrix is:
#               precision    recall  f1-score   support
#
#            0       0.96      0.60      0.74       192
#            1       0.77      0.98      0.87       268
#
#     accuracy                           0.82       460
#    macro avg       0.87      0.79      0.80       460
# weighted avg       0.85      0.82      0.81       460

# %%
classifier=svm.SVC(kernel="rbf", C=1, degree=3, gamma="auto")
classifier.fit(x_train, y_train)

dt_pred = classifier.predict(x_train)

bn_matrix = pd.DataFrame(confusion_matrix(y_train, dt_pred),
                         index=classifier.classes_,
                         columns=classifier.classes_)

plt.figure()
print("\nThe confusion matrix is:")
ax = sns.heatmap(bn_matrix,annot=True, fmt='.4g', vmin=0, vmax=250)
plt.show()

print(classification_report(y_train, dt_pred))
# Out:
# The confusion matrix is:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       192
#            1       0.58      1.00      0.74       268
#
#     accuracy                           0.58       460
#    macro avg       0.29      0.50      0.37       460
# weighted avg       0.34      0.58      0.43       460
# D:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier=svm.SVC(kernel="poly", C=1, degree=2, gamma="auto")
classifier.fit(x_train, y_train)

dt_pred = classifier.predict(x_train)

bn_matrix = pd.DataFrame(confusion_matrix(y_train, dt_pred),
                         index=classifier.classes_,
                         columns=classifier.classes_)

plt.figure()
print("\nThe confusion matrix is:")
ax = sns.heatmap(bn_matrix,annot=True, fmt='.4g', vmin=0, vmax=250)
plt.show()

print(classification_report(y_train, dt_pred))
# Out:
# The confusion matrix is:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       192
#            1       0.58      1.00      0.74       268
#
#     accuracy                           0.58       460
#    macro avg       0.29      0.50      0.37       460
# weighted avg       0.34      0.58      0.43       460
# D:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
